# %%
import pandas as pd
import zipfile
import pandas as pd
import os
import json
import re
import ast
import matplotlib
import multiprocessing

# %% [markdown]
# ## Create Statistic files for English Tables

# %%
#Existing English Tables
existing = open("output-data/english_table_names.txt", 'r')
existing_english_tables = [line.replace('\n', '') for line in existing.readlines()]
len(existing_english_tables)

# %%
#New English Tables
new_english_tables = os.listdir('output-data/new-english-tables/')
len(new_english_tables)

# %%
def get_table_statistics(file_name):
    
    if file_name in existing:
        file = 'data/original-corpus-data/' + file_name
    else:
        file = 'output-data/new-english-tables/' + file_name
    
    
    df = pd.read_json(file, compression='gzip', lines=True)
    df.drop(['page_url'], axis=1, inplace=True)
    
    number_of_rows = len(df.index)
    column_count = len(df.columns)
    empty_cells = df.isna().sum().sum()
    total_cells = number_of_rows * column_count
    
    column_name_and_density = {}
    overall_table_density = int((total_cells - empty_cells)/total_cells *100)
    
    for index, column in df.isna().sum().iteritems():
        column_name_and_density[index] = int(((number_of_rows - column) / number_of_rows) * 100)
    
    return [ file_name, number_of_rows, column_count, column_name_and_density, overall_table_density ]

# %%
pool = multiprocessing.Pool(processes=20)
res = pool.map(get_table_statistics, existing + new_english_tables)
pool.close()
pool.join()

# %%
statistics = pd.DataFrame(res, columns=['file_name', 'number_of_rows', 'column_count', 'column_name_and_density', 'overall_table_density'])
statistics

# %% [markdown]
# ## Choose tables with at least 10 rows

# %%
minimum10 = statistics.loc[statistics['number_of_rows'] >= 10]
minimum10
# Out:
#                                                  file_name  number_of_rows  \
# 0         School_schoolscompared.com_September2020.json.gz              66
# 1            Park_discoverdupage.com_September2020.json.gz              12
# 2         Painting_josephraffael.com_September2020.json.gz              19
# 3          Park_visitnordjylland.com_September2020.json.gz              26
# 4         Park_visithoustontexas.com_September2020.json.gz              15
# ...                                                    ...             ...
# 1795120   Product_leickert-dental.de_September2020.json.gz             156
# 1795121  Product_marijuanabudsstore.com_September2020.j...              35
# 1795124  Product_tomjanuaryfloors.com_September2020.jso...            1043
# 1795125       Product_shop-kvplus.ru_September2020.json.gz             206
# 1795126     Product_gellifique.co.uk_September2020.json.gz             144
#
#          column_count                            column_name_and_density  \
# 0                   3  {'name': 100, 'telephone': 100, 'aggregaterati...
# 1                   5  {'name': 100, 'address': 100, 'description': 1...
# 2                   9  {'name': 100, 'description': 100, 'author': 52...
# 3                   7  {'name': 100, 'address': 100, 'description': 1...
# 4                   5  {'name': 100, 'address': 100, 'description': 1...
# ...               ...                                                ...
# 1795120             7  {'name': 100, 'offers': 100, 'description': 10...
# 1795121             5  {'name': 100, 'offers': 100, 'description': 10...
# 1795124             6  {'name': 100, 'offers': 100, 'description': 10...
# 1795125             3   {'name': 100, 'offers': 100, 'description': 100}
# 1795126             6  {'name': 100, 'offers': 100, 'description': 53...
#
#          overall_table_density
# 0                          100
# 1                           98
# 2                           67
# 3                           86
# 4                           88
# ...                        ...
# 1795120                     91
# 1795121                     92
# 1795124                    100
# 1795125                    100
# 1795126                     67
#
# [1058129 rows x 5 columns]

# %% [markdown]
# ## Column Names Statistics
# Re-arrange tables by unique column names.

# %%
min10_dict = minimum10.to_dict('records')

# %%
min10_dict[0]
# Out:
# {'file_name': 'School_schoolscompared.com_September2020.json.gz',
#  'number_of_rows': 66,
#  'column_count': 3,
#  'column_name_and_density': "{'name': 100, 'telephone': 100, 'aggregaterating': 100}",
#  'overall_table_density': 100}

# %%
#Add to a dictionary column names grouped by their class as keys and number of rows, columns and file_names as values
colnames = {}
for row in min10_dict:
    class_ = row['file_name'].split('_')[0]
    cols = ast.literal_eval(row['column_name_and_density'])
    
    if class_ not in colnames:
        colnames[class_] = {}
    
    for col in cols:
        if col in colnames[class_]:
            colnames[class_][col].append([row['number_of_rows'], cols[col], row['file_name'], row['overall_table_density']])
        else:
            colnames[class_][col] = [[row['number_of_rows'], cols[col], row['file_name'], row['overall_table_density']]]

# %%
#Turn the dictionary with the column names into a dataframe
allcols = []
for classes in colnames:
    for colname in colnames[classes]:
        total_rows = 0
        tables_and_density = {}
        
        for tabs in colnames[classes][colname]:
            total_rows += tabs[0]
            #Museum_takemetotheworld.com_September2020.json.gz: overall_table_density, column density in this table
            tables_and_density[tabs[2]] = [tabs[3], tabs[1]] 
        
        allcols.append([classes, colname, len(colnames[classes][colname]), total_rows, tables_and_density])

# %%
all_cols = pd.DataFrame(allcols, columns=['class', 'column_name', 'table_number', 'row_number', 'table_and_density'])
all_cols
# Out:
#        class      column_name  table_number  row_number  \
# 0     School             name           145       85319
# 1     School        telephone            72       52788
# 2     School  aggregaterating            43       37264
# 3     School          address           124       78550
# 4     School              geo            23        2830
# ...      ...              ...           ...         ...
# 6129  Recipe   recipecooktime             1          15
# 6130  Recipe         mentions             1         103
# 6131  Recipe     reviewrating             1          63
# 6132  Recipe    discussionurl             1          24
# 6133  Recipe              sku             1          40
#
#                                       table_and_density
# 0     {'School_schoolscompared.com_September2020.jso...
# 1     {'School_schoolscompared.com_September2020.jso...
# 2     {'School_schoolscompared.com_September2020.jso...
# 3     {'School_ville-data.com_September2020.json.gz'...
# 4     {'School_ville-data.com_September2020.json.gz'...
# ...                                                 ...
# 6129  {'Recipe_marubotana.tv_September2020.json.gz':...
# 6130  {'Recipe_uol.com.br_September2020.json.gz': [9...
# 6131  {'Recipe_99juices.com_September2020.json.gz': ...
# 6132  {'Recipe_manjoo.it_September2020.json.gz': [10...
# 6133  {'Recipe_spirit-of-spice.de_September2020.json...
#
# [6134 rows x 5 columns]

# %% [markdown]
# ## Match to Schema.org Properties and Types

# %%
#For each property file, read its propstotypes file and match expected types
result_all = []

for index, row in all_cols.iterrows():
    col_name = str(row['column_name'])
    class_ = row['class']
        
    types = pd.read_csv('../PropsToTypes/' + class_ + '_propsToTypes.csv')
    find_label = (row['class'] + '.' + str(row['column_name'])).lower()
    is_label = types.loc[ types['property'].str.lower() == find_label ]
    
    final_label = ''
    final_type = ''

    if(len(is_label) != 0):
        idx = is_label.index.tolist()[0]
        final_label = is_label['property'][idx]
        final_type = is_label['expected_types'][idx]

    result_all.append([class_, col_name, final_label, final_type, row['table_number'], row['row_number'], row['table_and_density']])

# %%
cols_to_schema = pd.DataFrame(result_all, columns=['class', 'column_name', 'relation_label', 'type_label', 'table_number','row_number','table_and_density'])
cols_to_schema
# Out:
#        class      column_name          relation_label  \
# 0     School             name             School.name
# 1     School        telephone        School.telephone
# 2     School  aggregaterating  School.aggregateRating
# 3     School          address          School.address
# 4     School              geo              School.geo
# ...      ...              ...                     ...
# 6129  Recipe   recipecooktime
# 6130  Recipe         mentions         Recipe.mentions
# 6131  Recipe     reviewrating
# 6132  Recipe    discussionurl    Recipe.discussionUrl
# 6133  Recipe              sku
#
#                           type_label  table_number  row_number  \
# 0                               Text           145       85319
# 1                               Text            72       52788
# 2                    AggregateRating            43       37264
# 3          ['PostalAddress', 'Text']           124       78550
# 4     ['GeoCoordinates', 'GeoShape']            23        2830
# ...                              ...           ...         ...
# 6129                                             1          15
# 6130                           Thing             1         103
# 6131                                             1          63
# 6132                             URL             1          24
# 6133                                             1          40
#
#                                       table_and_density
# 0     {'School_schoolscompared.com_September2020.jso...
# 1     {'School_schoolscompared.com_September2020.jso...
# 2     {'School_schoolscompared.com_September2020.jso...
# 3     {'School_ville-data.com_September2020.json.gz'...
# 4     {'School_ville-data.com_September2020.json.gz'...
# ...                                                 ...
# 6129  {'Recipe_marubotana.tv_September2020.json.gz':...
# 6130  {'Recipe_uol.com.br_September2020.json.gz': [9...
# 6131  {'Recipe_99juices.com_September2020.json.gz': ...
# 6132  {'Recipe_manjoo.it_September2020.json.gz': [10...
# 6133  {'Recipe_spirit-of-spice.de_September2020.json...
#
# [6134 rows x 7 columns]

# %% [markdown]
# ### Matching to all properties regardless of type

# %%
#Filter out column names that did not match any schema.org property = are wrong
cols = cols_to_schema.loc[(cols_to_schema['relation_label'] != '')]
cols
# Out:
#        class      column_name          relation_label  \
# 0     School             name             School.name
# 1     School        telephone        School.telephone
# 2     School  aggregaterating  School.aggregateRating
# 3     School          address          School.address
# 4     School              geo              School.geo
# ...      ...              ...                     ...
# 6114  Recipe  locationcreated  Recipe.locationCreated
# 6118  Recipe          version          Recipe.version
# 6119  Recipe  contentlocation  Recipe.contentLocation
# 6130  Recipe         mentions         Recipe.mentions
# 6132  Recipe    discussionurl    Recipe.discussionUrl
#
#                           type_label  table_number  row_number  \
# 0                               Text           145       85319
# 1                               Text            72       52788
# 2                    AggregateRating            43       37264
# 3          ['PostalAddress', 'Text']           124       78550
# 4     ['GeoCoordinates', 'GeoShape']            23        2830
# ...                              ...           ...         ...
# 6114                           Place             1          14
# 6118              ['Number', 'Text']             2          91
# 6119                           Place             2        1300
# 6130                           Thing             1         103
# 6132                             URL             1          24
#
#                                       table_and_density
# 0     {'School_schoolscompared.com_September2020.jso...
# 1     {'School_schoolscompared.com_September2020.jso...
# 2     {'School_schoolscompared.com_September2020.jso...
# 3     {'School_ville-data.com_September2020.json.gz'...
# 4     {'School_ville-data.com_September2020.json.gz'...
# ...                                                 ...
# 6114  {'Recipe_cailler.ch_September2020.json.gz': [9...
# 6118  {'Recipe_guideme.me_September2020.json.gz': [8...
# 6119  {'Recipe_arecetas.com_September2020.json.gz': ...
# 6130  {'Recipe_uol.com.br_September2020.json.gz': [9...
# 6132  {'Recipe_manjoo.it_September2020.json.gz': [10...
#
# [1668 rows x 7 columns]

# %%
cols.to_csv('output-data/statistics/column_label_mapping.csv', index=False)
